# %% [markdown]
# ## Parameter identification for various models
#
# To investigate the performance of parameter identification for different electrochemical models we will start with synthetic data from the highest order model in PyBOP (Many-particle DFN) and try to identify the correct parameter values on the reduced order models.
#
# ### Setting up the Environment
#
# Before we begin, we need to ensure that we have all the necessary tools. We will install PyBOP and upgrade dependencies:

# %%
# %pip install --upgrade pip ipywidgets pybamm -q
# %pip install pybop -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next, we import the added packages plus any additional dependencies,

# %%
import numpy as np
import pybamm

import pybop

go = pybop.plot.PlotlyManager().go
pybop.plot.PlotlyManager().pio.renderers.default = "notebook_connected"

# %% [markdown]
# Let's fix the random seed in order to generate consistent output during development, although this does not need to be done in practice.

# %%
np.random.seed(8)

# %% [markdown]
# ## Optimising the Parameters

# %% [markdown]
# First, we define the model to be used for the parameter optimisation,

# %%
parameter_set = pybop.ParameterSet("Chen2020")
parameter_set = pybamm.get_size_distribution_parameters(parameter_set)
synth_model = pybop.lithium_ion.DFN(
    parameter_set=parameter_set,
    options={"particle size": "distribution"},
)
# Out:
# <pybop.parameters.parameter_set.ParameterSet object at 0x00000150A9B5BD50>

# %% [markdown]
# ### Simulating Forward Model
#
# We can then simulate the model using the `predict` method, with a default constant current to generate voltage data.

# %%
n_points = 350
t_eval = np.linspace(0, 1600 + 1000, n_points)
current = np.concatenate(
    [np.ones(100) * parameter_set["Nominal cell capacity [A.h]"], np.zeros(250)]
)
initial_state = {"Initial SoC": 0.5}

# %%
dataset = pybop.Dataset(
    {
        "Time [s]": t_eval,
        "Current function [A]": current,
    }
)

# %%
synth_model.build(dataset=dataset, initial_state=initial_state)
synth_model.signal = ["Voltage [V]"]
values = synth_model.simulate(t_eval=t_eval, inputs={})

# %% [markdown]
# ### Adding Noise to Voltage Data
#
# To make the parameter estimation more realistic, we add Gaussian noise to the data.

# %%
sigma = 0.001
corrupt_values = values["Voltage [V]"].data + np.random.normal(
    0, sigma, len(values["Voltage [V]"].data)
)
go.Figure(
    data=go.Scatter(x=t_eval, y=corrupt_values, mode="lines"),
    layout=go.Layout(title="Corrupted Voltage", width=800, height=600),
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="8d537de4-aaf9-43dd-bc3c-8c76a437a860" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8d537de4-aaf9-43dd-bc3c-8c76a437a860")) {                    Plotly.newPlot(                        "8d537de4-aaf9-43dd-bc3c-8c76a437a860",                        [{"mode":"lines","x":{"dtype":"f8","bdata":"\\u002fptajiR3dA9E+vRRW\u002fd0DqtajiRzZ4QOAbon96rXhA1oGbHK0keUDL55S535t5QMFNjlYSE3pAt7OH80SKekCtGYGQdwF7QKJ\u002fei2qeHtAmOVzytzve0COS21nD2d8QISxZgRC3nxAeRdgoXRVfUBvfVk+p8x9QGXjUtvZQ35AWklMeAy7fkBQr0UVPzJ\u002fQEYVP7JxqX9Anj2cJ1IQgECZ8Bh260uAQJSjlcSEh4BAjlYSEx7DgECJCY9ht\u002f6AQIS8C7BQOoFAf2+I\\u002f6bWo4keHQPqcMvd7g4dA9E+vRRW\u002fh0DvAiyUrvqHQOq1qOJHNohA5Wgl
# %% [markdown]
# ## Identifying the Parameters

# %% [markdown]
# We will now set up the parameter estimation process by defining the datasets for optimisation and selecting the model parameters we wish to estimate.

# %% [markdown]
# ### Creating a Dataset
#
# The dataset for optimisation is composed of time, current, and the noisy voltage data:

# %%
dataset = pybop.Dataset(
    {
        "Time [s]": t_eval,
        "Current function [A]": current,
        "Voltage [V]": corrupt_values,
    }
)

# %% [markdown]
# Next, we define the model parameters for optimisation. Furthermore, PyBOP provides functionality to define a prior for the parameters. The initial parameter values used in the optimisation will be randomly drawn from the prior distribution.

# %%
parameters = pybop.Parameters(
    pybop.Parameter(
        "Positive electrode thickness [m]",
        prior=pybop.Gaussian(7.56e-05, 0.05e-05),
        bounds=[65e-06, 85e-06],
        true_value=parameter_set["Positive electrode thickness [m]"],
    ),
    pybop.Parameter(
        "Negative electrode thickness [m]",
        prior=pybop.Gaussian(8.52e-05, 0.05e-05),
        bounds=[75e-06, 95e-06],
        true_value=parameter_set["Negative electrode thickness [m]"],
    ),
)

# %% [markdown]
# We can now define the output signal, the problem (which combines the model with the dataset) and construct a cost function which in this example is the `GravimetricEnergyDensity()` used to maximise the gravimetric energy density of the cell.

# %%
models = [
    pybop.empirical.Thevenin(parameter_set=parameter_set, options={"number of rc elements": 2}),   
]

# %% [markdown]
# Let's construct PyBOP's optimisation class for each model. This class provides the methods needed to fit the forward model. For this example, we use an evolution strategy (XNES) as the optimiser.

# %%
optims = []
xs = []
for model in models:
    print(f"Running {model.name}")
    #model.set_initial_state(initial_state)
    problem = pybop.FittingProblem(model, parameters, dataset)
    cost = pybop.SumSquaredError(problem)
    optim = pybop.XNES(
        cost,
        verbose=True,
        max_iterations=60,
        max_unchanged_iterations=10,
        population_size=5,
    )
    results = optim.run()
    optims.append(optim)
    xs.append(results.x)
# Out:
# Running Equivalent Circuit Thevenin Model
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(0x50472b4e92102b77, *, children=['0.0002777777777777778', '-Current function [A] / Cell capacity [A.h]'], domains={})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Division(0x40242014a4717186, /, children=['-Current function [A]', 'Cell capacity [A.h]'], domains={})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Parameter(0x26f9176eca562d80, Cell capacity [A.h], children=[], domains={})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\util.py:32, in FuzzyDict.__getitem__(self, key)
#      31 try:
# ---> 32     return super().__getitem__(key)
#      33 except KeyError as error:
#
# KeyError: 'Cell capacity [A.h]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 6
#       4 print(f"Running {model.name}")
#       5 #model.set_initial_state(initial_state)
# ----> 6 problem = pybop.FittingProblem(model, parameters, dataset)
#       7 cost = pybop.SumSquaredError(problem)
#       8 optim = pybop.XNES(
#       9     cost,
#      10     verbose=True,
#    (...)     13     population_size=5,
#      14 )
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybop\problems\fitting_problem.py:85, in FittingProblem.__init__(self, model, parameters, dataset, check_model, signal, domain, additional_variables, initial_state)
#      83 if self._model.built_model is not None:
#      84     self._model.clear()
# ---> 85 self._model.build(
#      86     dataset=self._dataset,
#      87     parameters=self.parameters,
#      88     check_model=self.check_model,
#      89     initial_state=self.initial_state,
#      90 )
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybop\models\base_model.py:185, in BaseModel.build(self, parameters, inputs, initial_state, dataset, check_model)
#     183     self._built_model = self.pybamm_model
#     184 else:
# --> 185     self.set_parameters()
#     186     self._mesh = pybamm.Mesh(self.geometry, self.submesh_types, self.var_pts)
#     187     self._disc = pybamm.Discretisation(
#     188         mesh=self.mesh,
#     189         spatial_methods=self.spatial_methods,
#     190         check_model=check_model,
#     191     )
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybop\models\base_model.py:279, in BaseModel.set_parameters(self)
#     276 if self._model_with_set_params:
#     277     return
# --> 279 self._model_with_set_params = self._parameter_set.process_model(
#     280     self._unprocessed_model, inplace=False
#     281 )
#     282 self._parameter_set.process_geometry(self._geometry)
#     283 self.pybamm_model = self._model_with_set_params
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:497, in ParameterValues.process_model(self, unprocessed_model, inplace)
#     495     pybamm.logger.verbose(f"Processing parameters for {variable!r} (rhs)")
#     496     new_variable = self.process_symbol(variable)
# --> 497     new_rhs[new_variable] = self.process_symbol(equation)
#     498 model.rhs = new_rhs
#     500 new_algebraic = {}
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:799, in ParameterValues._process_symbol(self, symbol)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:799, in <listcomp>(.0)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:799, in ParameterValues._process_symbol(self, symbol)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:799, in <listcomp>(.0)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:669, in ParameterValues._process_symbol(self, symbol)
#     666 """See :meth:`ParameterValues.process_symbol()`."""
#     668 if isinstance(symbol, pybamm.Parameter):
# --> 669     value = self[symbol.name]
#     670     if isinstance(value, numbers.Number):
#     671         # Check not NaN (parameter in csv file but no value given)
#     672         if np.isnan(value):
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:188, in ParameterValues.__getitem__(self, key)
#     178     raise KeyError(
#     179         "'Exchange-current density for plating [A.m-2]' has been renamed "
#     180         "to 'Exchange-current density for lithium metal electrode [A.m-2]' "
#    (...)    185         "the new name."
#     186     ) from err
#     187 else:
# --> 188     raise err
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\parameters\parameter_values.py:171, in ParameterValues.__getitem__(self, key)
#     169 def __getitem__(self, key):
#     170     try:
# --> 171         return self._dict_items[key]
#     172     except KeyError as err:
#     173         if (
#     174             "Exchange-current density for lithium metal electrode [A.m-2]"
#     175             in err.args[0]
#     176             and "Exchange-current density for plating [A.m-2]" in self._dict_items
#     177         ):
#
# File c:\Users\frw21\OneDrive - Imperial College London\2025 UROP projects - ME - FELIX-PyBAMM\Technical\ESE_UROP_2025\venv\Lib\site-packages\pybamm\util.py:90, in FuzzyDict.__getitem__(self, key)
#      84     elif key in k and (
#      85         k.startswith("Primary") or k.startswith("Secondary")
#      86     ):
#      87         raise KeyError(
#      88             f"'{key}' not found. If you are using a composite model, you may need to use {k} instead. Otherwise, best matches are {best_matches}"
#      89         ) from error
# ---> 90 raise KeyError(
#      91     f"'{key}' not found. Best matches are {best_matches}"
#      92 ) from error
#
# KeyError: "'Cell capacity [A.h]' not found. Best matches are ['Nominal cell capacity [A.h]']"

# %%
for optim, x in zip(optims, xs):
    print(f"| Model: {optim.cost.problem.model.name} | Results: {x} |")
# Out:
# | Model: Single Particle Model | Results: [6.50239331e-05 8.31346140e-05] |
# | Model: Single Particle Model with Electrolyte | Results: [7.42990350e-05 8.10714586e-05] |

# %% [markdown]
# ## Plotting and Visualisation
#
# PyBOP provides various plotting utilities to visualise the results of the optimisation.

# %% [markdown]
# ### Comparing System Response
#
# We can quickly plot the system's response using the estimated parameters compared to the initial parameters:

# %%
for optim, x in zip(optims, xs):
    pybop.plot.problem(
        optim.cost.problem, problem_inputs=x, title=optim.cost.problem.model.name
    )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id